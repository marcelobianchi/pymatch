# %%
import Match
import os
# %matplotlib inline

# %%
reload(Match)
# Out:
# <module 'Match' from 'Match.pyc'>

# %% [markdown]
# # Serie Test

# %%
s = Match.Serie("LR04core")
s.report()
# Out:
# Serie: Label: Noname Filename: LR04core
#
# Statistics:            Full / Window
#  Number of Points:      501 / 501
#             x-Min: 0.000000 / 500.000000
#             y-Min: 3.100000 / 3.100000
#             y-Max: 5.080000 / 5.080000
#            y-Mean: 4.155868 / 4.155868
#           y-StdEv: 0.474612 / 0.474612
#
# Associated Information:
#    Begin is: None and End is: None
#    Total of 0 tie points.

# %%
s.plot()

# %% [markdown]
# ## Set Limits

# %%
s = Match.Serie("LR04core")
s.setLimits(1000, 3000).plot()

# %%
s.setLimits(1000,3000, True).plot()

# %% [markdown]
# ## Normalize

# %%
s = Match.Serie("LR04core")

# %%
s.normalize(True).plot()

# %%
s.normalize(False).plot()

# %%
s.normalize(False, s.normalizeStd()).plot()

# %%
s.normalizeStd(True).plot()

# %%
s.normalizeStd(False).plot()

# %%
s.setLimits(1000, 3000, True).plot()

# %%
s.setTie("A", 1250).setTie("B", 2250).plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-727805416a5e> in <module>()
# ----> 1 s.setTie("A", 1250).setTie("B", 2250).plot()
#
# /home/mbianchi/Work/pymatch/Match.pyc in setTie(self, label, value)
#     209
#     210     def setTie(self, label, value):
# --> 211         if value < self.x.min() or value > self.x.max():
#     212             raise Exception("Bad Tie Value = %f, outside of series x-definition range %f to %f." % (value,self.x.min(), self.x.max()))
#     213
#
# /home/mbianchi/.local/miniconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
s.save()

# %%
s.saveas("teste.dat")

# %%
os.unlink("teste.dat")
